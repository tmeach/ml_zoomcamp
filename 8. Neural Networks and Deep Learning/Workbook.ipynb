# %% [markdown]
# ## 8.2  TensorFlow and Keras
# - Installing TensorFlow
# - Loading images

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
import tensorflow as tf
from tensorflow import keras
# Out:
# 2023-11-13 22:45:40.800203: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-13 22:45:41.273265: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-13 22:45:41.274957: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-13 22:45:42.929824: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
from tensorflow.keras.preprocessing.image import

# %%
path = './clothing-dataset-small/train/t-shirt'
name = '5f0a3fa0-6a3d-4b68-b213-72766a643de7.jpg'
fullname = f'{path}/{name}'

# %%
load_img(fullname)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x533>

# %%
img = load_img(fullname, target_size=(150, 150))

# %%
print(img)
# Out:
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7FF4E523EF70>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
np.array(img)
# Out:
# array([[[177, 169,  97],
#         [178, 169, 100],
#         [182, 173, 104],
#         ...,
#         [251, 253, 250],
#         [251, 253, 248],
#         [251, 254, 247]],
#
#        [[200, 190, 128],
#         [203, 193, 132],
#         [203, 193, 132],
#         ...,
#         [250, 251, 246],
#         [250, 251, 245],
#         [250, 251, 245]],
#
#        [[200, 189, 133],
#         [203, 192, 136],
#         [202, 191, 135],
#         ...,
#         [253, 250, 245],
#         [252, 249, 242],
#         [251, 248, 239]],
#
#        ...,
#
#        [[171, 157,  82],
#         [170, 156,  81],
#         [171, 157,  82],
#         ...,
#         [184, 142,  32],
#         [180, 133,  25],
#         [182, 135,  27]],
#
#        [[171, 157,  82],
#         [170, 156,  81],
#         [171, 157,  82],
#         ...,
#         [187, 144,  32],
#         [179, 132,  24],
#         [181, 134,  26]],
#
#        [[170, 156,  81],
#         [171, 157,  82],
#         [170, 156,  81],
#         ...,
#         [184, 138,  26],
#         [182, 134,  23],
#         [181, 133,  22]]], dtype=uint8)
