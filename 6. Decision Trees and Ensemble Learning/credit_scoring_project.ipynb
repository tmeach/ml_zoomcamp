# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 6.2 Data cleaning and preparation
#
# - Downloading the dataset
# - Re-encoding the categorical variables
# - Doing the train/validation/test split

# %%
df = pd.read_csv("/home/timur/work_hub/ml_zoomcamp2023/6. Decision Trees and Ensemble Learning/CreditScoring.csv")

# %%
df.head()
# Out:
#    Status  Seniority  Home  Time  Age  Marital  Records  Job  Expenses  \
# 0       1          9     1    60   30        2        1    3        73
# 1       1         17     1    60   58        3        1    1        48
# 2       2         10     2    36   46        2        2    3        90
# 3       1          0     1    60   24        1        1    1        63
# 4       1          0     1    36   26        1        1    1        46
#
#    Income  Assets  Debt  Amount  Price
# 0     129       0     0     800    846
# 1     131       0     0    1000   1658
# 2     200    3000     0    2000   2985
# 3     182    2500     0     900   1325
# 4     107       0     0     310    910

# %% [markdown]
# Set lower register for our columns

# %%
df.columns = df.columns.str.lower()
df.columns
# Out:
# Index(['status', 'seniority', 'home', 'time', 'age', 'marital', 'records',
#        'job', 'expenses', 'income', 'assets', 'debt', 'amount', 'price'],
#       dtype='object')

# %%
df.head()
# Out:
#    status  seniority  home  time  age  marital  records  job  expenses  \
# 0       1          9     1    60   30        2        1    3        73
# 1       1         17     1    60   58        3        1    1        48
# 2       2         10     2    36   46        2        2    3        90
# 3       1          0     1    60   24        1        1    1        63
# 4       1          0     1    36   26        1        1    1        46
#
#    income  assets  debt  amount  price
# 0     129       0     0     800    846
# 1     131       0     0    1000   1658
# 2     200    3000     0    2000   2985
# 3     182    2500     0     900   1325
# 4     107       0     0     310    910

# %% [markdown]
# We see that there're several categorical columns in our dataset but it's look like numbers. Let's convert it to categories to figure out what going on.

# %%
status_values = {
    1:'ok',
    2:'default',
    3:'unk'
}

df.status = df.status.map(status_values)

# %%
home_values = {
    1: 'rent',
    2: 'owner',
    3: 'private',
    4: 'ignore',
    5: 'parents',
    6: 'other',
    0: 'unk'
}

df.home = df.home.map(home_values)

marital_values = {
    1: 'single',
    2: 'married',
    3: 'widow',
    4: 'separated',
    5: 'divorced',
    0: 'unk'
}

df.marital = df.marital.map(marital_values)

records_values = {
    1: 'no',
    2: 'yes',
    0: 'unk'
}

df.records = df.records.map(records_values)

job_values = {
    1: 'fixed',
    2: 'partime',
    3: 'freelance',
    4: 'others',
    0: 'unk'
}

df.job = df.job.map(job_values)

# %%
df.describe().round()
# Out:
#        seniority    time     age  expenses      income      assets  \
# count     4455.0  4455.0  4455.0    4455.0      4455.0      4455.0
# mean         8.0    46.0    37.0      56.0    763317.0   1060341.0
# std          8.0    15.0    11.0      20.0   8703625.0  10217569.0
# min          0.0     6.0    18.0      35.0         0.0         0.0
# 25%          2.0    36.0    28.0      35.0        80.0         0.0
# 50%          5.0    48.0    36.0      51.0       120.0      3500.0
# 75%         12.0    60.0    45.0      72.0       166.0      6000.0
# max         48.0    72.0    68.0     180.0  99999999.0  99999999.0
#
#              debt  amount    price
# count      4455.0  4455.0   4455.0
# mean     404382.0  1039.0   1463.0
# std     6344253.0   475.0    628.0
# min           0.0   100.0    105.0
# 25%           0.0   700.0   1118.0
# 50%           0.0  1000.0   1400.0
# 75%           0.0  1300.0   1692.0
# max    99999999.0  5000.0  11140.0

# %%
df.income.max()
# Out:
# 99999999

# %% [markdown]
# We have 99999999 values in income, assets and debt columns, which actually means nan values. Let's replace this to nan

# %%
for c in ['income', 'assets', 'debt']:
    df[c] = df[c].replace(to_replace=99999999, value=np.nan)

# %%
df.describe().round()
# Out:
#        seniority    time     age  expenses  income    assets     debt  amount  \
# count     4455.0  4455.0  4455.0    4455.0  4421.0    4408.0   4437.0  4455.0
# mean         8.0    46.0    37.0      56.0   131.0    5403.0    343.0  1039.0
# std          8.0    15.0    11.0      20.0    86.0   11573.0   1246.0   475.0
# min          0.0     6.0    18.0      35.0     0.0       0.0      0.0   100.0
# 25%          2.0    36.0    28.0      35.0    80.0       0.0      0.0   700.0
# 50%          5.0    48.0    36.0      51.0   120.0    3000.0      0.0  1000.0
# 75%         12.0    60.0    45.0      72.0   165.0    6000.0      0.0  1300.0
# max         48.0    72.0    68.0     180.0   959.0  300000.0  30000.0  5000.0
#
#          price
# count   4455.0
# mean    1463.0
# std      628.0
# min      105.0
# 25%     1118.0
# 50%     1400.0
# 75%     1692.0
# max    11140.0

# %% [markdown]
# Train/validation/test split

# %%
from sklearn.model_selection import train_test_split

# %%
df_full_train, df_test = train_test_split(df, test_size=0.2, random_state=11)

# %%
df_train, df_val = train_test_split(df_full_train, test_size=0.25, random_state=11)

# %%
df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

# %%
y_train = (df_train.status == 'default').astype('int')
y_val = (df_val.status == 'default').astype('int')
y_test = (df_test.status == 'default').astype('int')

# %%
del df_train['status']
del df_val['status']
del df_test['status']

# %%
df_train
# Out:
#       seniority     home  time  age    marital records        job  expenses  \
# 0             3     rent    36   61    married      no      fixed        41
# 1             5     rent    48   30  separated     yes    partime        39
# 2            15    owner    60   32   divorced      no  freelance        35
# 3             2     rent    12   47    married     yes      fixed       103
# 4             6  parents    48   32     single     yes      fixed        35
# ...         ...      ...   ...  ...        ...     ...        ...       ...
# 2668          1  parents    60   21     single      no    partime        35
# 2669          5     rent    60   47     single     yes      fixed        46
# 2670         23     rent    24   47     single      no      fixed        44
# 2671          5    owner    60   58    married      no  freelance        45
# 2672          4    owner    48   22    married      no      fixed        35
#
#       income   assets    debt  amount  price
# ...

# %% [markdown]
# ## 6.3 Decision trees
#
#
# - How a decision three looks like
# - Training a decision tree
# - Overfitting
# - Controlling the size of a tree

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Let's represent it in Python code

# %%
def assess_risk(client):
    if client['records'] == 'yes':
        if client['job'] == 'parttime':
            return 'default'
        else:
            return 'ok'
        
    else:
        if client['assets'] > 6000:
            return 'ok'
        else:
            return 'default'

# %%
xi = df_train.iloc[0].to_dict()

# %% [markdown]
# Let's check this cleint with our decision tree model

# %%
assess_risk(xi)
# Out:
# 'ok'

# %% [markdown]
# We did it manually but actually we can (and we have) to use scikit-learn library

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.feature_extraction import DictVectorizer
from sklearn.metrics import roc_auc_score

# %%
train_dicts = df_train.fillna(0).to_dict(orient='records')

# %%
dv = DictVectorizer(sparse=False)
X_train = dv.fit_transform(train_dicts)

# %% [markdown]
# Feature matrix

# %%
X_train
# Out:
# array([[6.10e+01, 2.50e+03, 1.20e+04, ..., 0.00e+00, 3.00e+00, 3.60e+01],
#        [3.00e+01, 1.30e+03, 0.00e+00, ..., 1.00e+00, 5.00e+00, 4.80e+01],
#        [3.20e+01, 1.55e+03, 6.00e+03, ..., 0.00e+00, 1.50e+01, 6.00e+01],
#        ...,
#        [4.70e+01, 3.50e+02, 0.00e+00, ..., 0.00e+00, 2.30e+01, 2.40e+01],
#        [5.80e+01, 1.50e+03, 4.50e+04, ..., 0.00e+00, 5.00e+00, 6.00e+01],
#        [2.20e+01, 1.25e+03, 1.00e+04, ..., 0.00e+00, 4.00e+00, 4.80e+01]])

# %% [markdown]
# Feature names

# %%
dv.get_feature_names()
# Out:
# /home/timur/.local/lib/python3.8/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ['age',
#  'amount',
#  'assets',
#  'debt',
#  'expenses',
#  'home=ignore',
#  'home=other',
#  'home=owner',
#  'home=parents',
#  'home=private',
#  'home=rent',
#  'home=unk',
#  'income',
#  'job=fixed',
#  'job=freelance',
#  'job=others',
#  'job=partime',
#  'marital=divorced',
#  'marital=married',
#  'marital=separated',
#  'marital=single',
#  'marital=unk',
#  'marital=widow',
#  'price',
#  'records=no',
#  'records=yes',
#  'seniority',
#  'time']

# %%
dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
val_dicts = df_val.fillna(0).to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
y_pred = dt.predict_proba(X_val)[:, 1]

# %%
roc_auc_score(y_val, y_pred)
# Out:
# 0.6640934993015982

# %% [markdown]
# We get 0.66 roc auc score and actually it's not impressive

# %% [markdown]
# ### Overfitting

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The reason is ________
#
#
# Let's retrain the tree but control the depth of tree

# %%
dt = DecisionTreeClassifier(max_depth=3)
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
y_pred = dt.predict_proba(X_train)[:, 1]
auc = roc_auc_score(y_train, y_pred)
print('train:', auc)

y_pred = dt.predict_proba(X_val)[:, 1]
auc = roc_auc_score(y_val, y_pred)
print('val:', auc )
# Out:
# train: 0.7660925386129352
# val: 0.763427236430611

# %% [markdown]
# So after we control the depth of our tree we improve performance of our tree

# %% [markdown]
# ### Decision stump (one condition)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
dt = DecisionTreeClassifier(max_depth=1)
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=1)

# %%
y_pred = dt.predict_proba(X_train)[:, 1]
auc = roc_auc_score(y_train, y_pred)
print('train:', auc)

y_pred = dt.predict_proba(X_val)[:, 1]
auc = roc_auc_score(y_val, y_pred)
print('val:', auc )
# Out:
# train: 0.6271176710091984
# val: 0.6131750701491985

# %% [markdown]
# Actually we have special tool in sklearn to vizualize how our tree works

# %%
from sklearn.tree import export_text

# %%
print(export_text(dt, feature_names=dv.get_feature_names()))
# Out:
# |--- records=no <= 0.50
# |   |--- class: 1
# |--- records=no >  0.50
# |   |--- class: 0
# /home/timur/.local/lib/python3.8/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# ### The decision tree with 2 levels

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
dt = DecisionTreeClassifier(max_depth=2)
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %%
y_pred = dt.predict_proba(X_train)[:, 1]
auc = roc_auc_score(y_train, y_pred)
print('train:', auc)

y_pred = dt.predict_proba(X_val)[:, 1]
auc = roc_auc_score(y_val, y_pred)
print('val:', auc )
# Out:
# train: 0.7017132266649385
# val: 0.6876073869887143
